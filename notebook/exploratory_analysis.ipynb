# %% [markdown]
# # Medical Insurance Premium Exploratory Data Analysis
# This notebook performs EDA and demonstrates the model training pipeline using modular components from the `src/` directory.

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path
sys.path.append(os.path.abspath('../src'))

from data_processing import load_data, preprocess_data
from models import ModelFactory, evaluate_model
from utils import plot_correlation_matrix, plot_distribution

# %%
data_path = '../data/Medicalpremium.csv'
df = load_data(data_path)
print(f"Dataset shape: {df.shape}")
df.head()

# %%
print("Dataset statistics:")
display(df.describe())

plt.figure(figsize=(10, 6))
sns.histplot(df['PremiumPrice'], bins=30, kde=True)
plt.title('Distribution of Premium Prices')
plt.show()

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
X_train, X_test, y_train, y_test, scaler, features = preprocess_data(df)

# Train and evaluate Random Forest
rf_model = ModelFactory.create_random_forest()
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

metrics = evaluate_model(y_test, y_pred)
print("Random Forest Performance:")
for k, v in metrics.items():
    print(f"  {k}: {v:.4f}")
